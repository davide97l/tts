# %%
#!sudo apt-get install espeak
#!pip install py-espeak-ng
# !sudo apt-get install espeak-ng
# !git clone https://github.com/coqui-ai/TTS
# %cd TTS
# !pip install -e .[all,dev,notebooks]  # Select the relevant extras

# %%
import torch

use_gpu = torch.cuda.is_available()

# %%
import os
from google.colab import files
import IPython
from TTS.api import TTS

tts = TTS(model_name="tts_models/multilingual/multi-dataset/your_tts", progress_bar=False, gpu=use_gpu)

def clone_voice(tts, text: str, voice: str = None):
  if voice.endswith('.wav'):
    voice = voice.split('.wav')[0]
  if not os.path.exists(f'{voice}.wav'):
    # select only one file
    for i, file_data in enumerate(files.upload().values()):
      with open(f'{voice}.wav', 'wb') as f:
        f.write(file_data)

  tts.tts_to_file(text, speaker_wav=f'{voice}.wav', language='en', file_path=f'output_{voice}.wav')
  return f'output_{voice}.wav'

# %%
# Tony Stark - short sentence

text = 'We must destroy all of them and revenge our planet'
voice = 'tony_stark'
voice = clone_voice(tts, text, voice)
IPython.display.Audio(voice)
# Out:
#      <input type="file" id="files-31d25edd-e9fb-4d70-8296-4b453f1437aa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-31d25edd-e9fb-4d70-8296-4b453f1437aa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Tony Stark - poem

text = \
'''In the morning light,
The world is new and bright.
Birds sing their sweet song,
As the day begins to dawn.'''
voice = 'tony_stark.wav'
voice = clone_voice(tts, text, voice)
IPython.display.Audio(voice)
# Out:
#  > Text splitted to sentences.
# ['In the morning light,', 'The world is new and bright.', 'Birds sing their sweet song,', 'As the day begins to dawn.']
#  > Processing time: 0.41844916343688965
#  > Real-time factor: 0.05302194164177517
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Tony Stark - explaining science

text = \
'''Dark holes are regions in space where the gravitational pull is so strong that nothing, not even light, can escape'''
voice = 'tony_stark.wav'
voice = clone_voice(tts, text, voice)
IPython.display.Audio(voice)
# Out:
#  > Text splitted to sentences.
# ['Dark holes are regions in space where the gravitational pull is so strong that nothing, not even light, can escape']
#  > Processing time: 0.18879413604736328
#  > Real-time factor: 0.02473393633530241
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Locky - short sentence

text = 'We must destroy all of them and revenge our planet'
voice = 'locky'
voice = clone_voice(tts, text, voice)
IPython.display.Audio(voice)
# Out:
#      <input type="file" id="files-0303d584-1a2c-4991-bc33-44572d2d8da0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0303d584-1a2c-4991-bc33-44572d2d8da0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Locky - poem

text = \
'''The flowers bloom with grace,
A smile on every face.
The sun shines down on all,
As we answer nature's call.'''
voice = 'locky.wav'
voice = clone_voice(tts, text, voice)
IPython.display.Audio(voice)
# Out:
#  > Text splitted to sentences.
# ['The flowers bloom with grace,', 'A smile on every face.', 'The sun shines down on all,', "As we answer nature's call."]
#  > Processing time: 0.4143986701965332
#  > Real-time factor: 0.03779630337436457
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Me - short sentence

text = 'We must destroy all of them and revenge our planet'
voice = 'me'
voice = clone_voice(tts, text, voice)
IPython.display.Audio(voice)
# Out:
#      <input type="file" id="files-9db49837-1094-4e50-a87b-22147ca4be3c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9db49837-1094-4e50-a87b-22147ca4be3c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Me - poem

text = '''So let us take a moment,
To appreciate this moment,
And cherish all that we see,
In this world so free.'''
voice = 'me.wav'
voice = clone_voice(tts, text, voice)
IPython.display.Audio(voice)
# Out:
#  > Text splitted to sentences.
# ['So let us take a moment,', 'To appreciate this moment,', 'And cherish all that we see,', 'In this world so free.']
#  > Processing time: 0.5781521797180176
#  > Real-time factor: 0.06700882935999276
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#from TTS.api import TTS
#import IPython

#tts = TTS("tts_models/en/sam/tacotron-DDC")
#tts.tts_with_vc_to_file(
#    "We must destroy all of them",
#    speaker_wav="weapon.wav",
#    file_path="ouptut.wav"
#)
#IPython.display.Audio('output.wav')

# %%
TTS.list_models()
# Out:
# No API token found for 🐸Coqui Studio voices - https://coqui.ai
# Visit 🔗https://app.coqui.ai/account to get one.
# Set it as an environment variable `export COQUI_STUDIO_TOKEN=<token>`
# ['tts_models/multilingual/multi-dataset/your_tts',
#  'tts_models/bg/cv/vits',
#  'tts_models/cs/cv/vits',
#  'tts_models/da/cv/vits',
#  'tts_models/et/cv/vits',
#  'tts_models/ga/cv/vits',
#  'tts_models/en/ek1/tacotron2',
#  'tts_models/en/ljspeech/tacotron2-DDC',
#  'tts_models/en/ljspeech/tacotron2-DDC_ph',
#  'tts_models/en/ljspeech/glow-tts',
#  'tts_models/en/ljspeech/speedy-speech',
#  'tts_models/en/ljspeech/tacotron2-DCA',
#  'tts_models/en/ljspeech/vits',
#  'tts_models/en/ljspeech/vits--neon',
#  'tts_models/en/ljspeech/fast_pitch',
#  'tts_models/en/ljspeech/overflow',
#  'tts_models/en/ljspeech/neural_hmm',
#  'tts_models/en/vctk/vits',
#  'tts_models/en/vctk/fast_pitch',
#  'tts_models/en/sam/tacotron-DDC',
#  'tts_models/en/blizzard2013/capacitron-t2-c50',
# ...
